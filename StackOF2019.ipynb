# %%
# Stack Overflow conducted an online survey of software professionals across the world.
# The data set that I have used below is a subset of the survey.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Imported necessary libraries.

# %%
df=pd.read_csv('C:\StackOF2019.csv')

# %%
pd.set_option('display.max_columns', 84)

# %%
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
dfOrig=df.copy()

# %%
df.shape
# Out:
# (11552, 85)

# %%
# Contains 11552 rows and 85 columns

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df.tail()
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 11547                                              Never
# 11548                                              Never
# 11549                            Less than once per year
# 11550  Less than once a month but more than once per ...
# 11551  Less than once a month but more than once per ...
#
#                                               OpenSource          Employment  \
# 11547  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11548  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
# Viewed the head and tail of the df to get a basic idea of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %%
# 5 Float, 1 int and 79 object datatype columns

# %%
df.isna().sum()
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       547
# Ethnicity       683
# Dependents      144
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %%
# NaN values in the dataset.

# %%
df.Age.isna().sum()
# Out:
# 297

# %%
# 297 NaN values in the Age column.

# %%
df1=df.copy()

# %%
df1.Age.fillna(df.Age.mean(),inplace=True)

# %%
# Imputing NaN values with the mean of Age column.

# %%
df1.Age.isna().sum()
# Out:
# 0

# %%
# Verifying whether NaN values were replaced.

# %%
df['Age']=df1['Age']

# %%
df.Age.mean()
# Out:
# 30.772394491337238

# %%
# Average age of the survey participants is 30.77 years.

# %%
df.Country.nunique()
# Out:
# 135

# %%
# Number of unique countries is 135

# %%
df1.duplicated().value_counts()
# Out:
# False    11398
# True       154
# dtype: int64

# %%
# 154 duplicate rows in the dataset

# %%
df1.drop_duplicates(inplace=True)

# %%
# Dropping duplicate rows

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11398 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11398 non-null  int64
#  1   MainBranch              11398 non-null  object
#  2   Hobbyist                11398 non-null  object
#  3   OpenSourcer             11398 non-null  object
#  4   OpenSource              11317 non-null  object
#  5   Employment              11398 non-null  object
#  6   Country                 11398 non-null  object
#  7   Student                 11347 non-null  object
#  8   EdLevel                 11286 non-null  object
#  9   UndergradMajor          10661 non-null  object
#  10  EduOther                11234 non-null  object
#  11  OrgSize                 11302 non-null  object
#  12  DevType                 11333 non-null  object
#  13  YearsCode               11389 non-null  object
# ...

# %%
df=df1

# %%
# 11398 non-duplicate rows remain after removing duplicates

# %%
df1.WorkLoc.head(10)
# Out:
# 0                                              Home
# 1                                            Office
# 2                                              Home
# 3                                              Home
# 4    Other place, such as a coworking space or cafe
# 5                                            Office
# 6                                            Office
# 7                                              Home
# 8                                            Office
# 9                                            Office
# Name: WorkLoc, dtype: object

# %%
df1.WorkLoc.isna().sum()
# Out:
# 32

# %%
# WorkLoc has 32 missing values

# %%
df1.WorkLoc.value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %%
# Work Location 'Office' occurs most frequently

# %%
df1.WorkLoc.mode()[0]
# Out:
# 'Office'

# %%
df1.WorkLoc.fillna(df1.WorkLoc.mode()[0],inplace=True)

# %%
# Fill missing values for Work Location with the most frequent value

# %%
df1.WorkLoc.isna().sum()
# Out:
# 0

# %%
# Verifying that missing values are filled

# %%
df=df1

# %%
df1.CompFreq.value_counts(dropna=False)
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# NaN         206
# Name: CompFreq, dtype: int64

# %%
# Whether paid yearly, monthly or weekly

# %%
df1.CompFreq.value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
NormalizedAnnualComp = pd.np.where(df1.CompFreq.str.contains('Yearly'),(df1.CompTotal),
                        pd.np.where(df1.CompFreq.str.contains('Monthly'),(df1.CompTotal*12),
                        pd.np.where(df1.CompFreq.str.contains('Weekly'),(df1.CompTotal*52),0)))

# %%
# Created NormalizedAnnualComp which represents the respondents' Yearly salary.

# %%
df['NormalizedAnnualComp']=NormalizedAnnualComp

# %%
# Added NormalizedAnnualComp to df as a new column

# %%
df.NormalizedAnnualComp.median()
# Out:
# 100000.0

# %%
# Median of Normalized annual compensation is 100,000.

# %%
df.shape
# Out:
# (11398, 86)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# ConvertedComp is the salary converted to annual USD salaries.

# %%
df.ConvertedComp.median()
# Out:
# 57745.0

# %%
# Median of ConvertedComp is $57,745.

# %%
df.ConvertedComp.hist()
# Out:
# <AxesSubplot:>

# %%
df.ConvertedComp.describe()
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df.groupby(df1.Gender).ConvertedComp.median()
# Out:
# Gender
# Man                                                            57744.0
# Man;Non-binary, genderqueer, or gender non-conforming          59520.0
# Non-binary, genderqueer, or gender non-conforming              67142.0
# Woman                                                          57708.0
# Woman;Man                                                      21648.0
# Woman;Man;Non-binary, genderqueer, or gender non-conforming    30244.0
# Woman;Non-binary, genderqueer, or gender non-conforming        65535.5
# Name: ConvertedComp, dtype: float64

# %%
# Median salaries of the respondents grouped by Genders.

# The median ConvertedComp of people who identify as ONLY as a woman is $57708.

# %%
df.Gender.isna().sum()
# Out:
# 73

# %%
# 73 NaN values in Gender

# %%
df2=df1[df1.Gender.notna()]
df2
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
# Dropped NaN Gender rows

# %%
df=df2

# %%
df.loc[df.Gender.str.contains('Woman',case=False)].ConvertedComp.median()
# Out:
# 57430.0

# %%
# Median ConvertedComp of people who have identified themselves as Woman is $57430.
# Includes people who have included Woman along with other genders.

# %%
df.Gender.value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %%
# Count of people who identify themselves as ONLY Man is 10480.
# Count of people who identify themselves as ONLY Woman is 731.

# %%
df3=df.loc[df.Gender.str.contains('Woman',case=False)]
df3.Gender.count()
# Out:
# 756

# %%
# Count of people who identify themselves as woman is 756.
# Includes people who have included Woman along with other genders.

# %%
df2.Age.describe()
# Out:
# count    11325.000000
# mean        30.777140
# std          7.287313
# min         16.000000
# 25%         26.000000
# 50%         29.000000
# 75%         34.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df2.Age.hist()
# Out:
# <AxesSubplot:>

# %%
# Concentrated between ages of 17 and 48.

# %%
sns.boxplot(df2.ConvertedComp)
# Out:
# <AxesSubplot:xlabel='ConvertedComp'>

# %%
df2.ConvertedComp.describe()
# Out:
# count    1.051200e+04
# mean     1.316710e+05
# std      2.949571e+05
# min      0.000000e+00
# 25%      2.686750e+04
# 50%      5.775100e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df2.ConvertedComp.isna().value_counts()
# Out:
# False    10512
# True       813
# Name: ConvertedComp, dtype: int64

# %%
df3=df2

# %%
df3.ConvertedComp.fillna(df3.ConvertedComp.median(),inplace=True)

# %%
df=df3

# %%
df3.MainBranch.value_counts(dropna=False)
# Out:
# I am a developer by profession                                                   10547
# I am not primarily a developer, but I write code sometimes as part of my work      778
# Name: MainBranch, dtype: int64

# %%
df4=df3

# %%
df4.MainBranch=df4.MainBranch.apply(lambda x:'Developer' if x=='I am a developer by profession' else 'Not a developer')

# %%
df4.MainBranch.value_counts()
# Out:
# Developer          10547
# Not a developer      778
# Name: MainBranch, dtype: int64

# %%
df4.MainBranch.value_counts().plot.barh(title='Role',color='green')
# Out:
# <AxesSubplot:title={'center':'Role'}>

# %%
df=df4

# %%
df5=df.copy()

# %%
Q1 = df5.ConvertedComp.quantile(0.25)
Q1
# Out:
# 29028.0

# %%
# Lower bound is $29028.

# %%
Q3 = df5.ConvertedComp.quantile(0.75)
Q3
# Out:
# 95000.0

# %%
# Upper bound is $95000.

# %%
IQR = Q3 - Q1
IQR
# Out:
# 65972.0

# %%
# Inter Quantile Range is $65972.

# %%
# Finding out Outliers

# %%
Outliers=df5[(df5.ConvertedComp < (Q1 - 1.5 * IQR)) |(df5.ConvertedComp > (Q3 + 1.5 * IQR))]
Outliers
# Out:
#        Respondent       MainBranch Hobbyist  \
# 3              16        Developer      Yes
# 13             32        Developer       No
# 45            100        Developer      Yes
# 46            102        Developer       No
# 60            128  Not a developer      Yes
# ...           ...              ...      ...
# 11450       24915        Developer      Yes
# 11457       24931        Developer       No
# 11504       25036        Developer      Yes
# 11507       25047        Developer      Yes
# 11523       25086        Developer      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 13                                                 Never
# 45                            Once a month or more often
# 46                                                 Never
# 60                            Once a month or more often
# ...                                                  ...
# ...

# %%
Outliers.ConvertedComp.count()
# Out:
# 927

# %%
# 927 outliers

# %%
df5.loc[(df5.ConvertedComp < (Q1 - 1.5 * IQR)) | (df5.ConvertedComp > (Q3 + 1.5 * IQR)),'ConvertedComp'] = np.nan

# %%
# Replacing outlier values of ConvertedComp with NaN.

# %%
df5.ConvertedComp.isna().sum()
# Out:
# 927

# %%
df5.Respondent.isna().sum()
# Out:
# 0

# %%
df5.ConvertedComp.fillna(df5.ConvertedComp.median(),inplace=True)

# %%
# Filling NaN values in ConvertedComp with its median.

# %%
df5.ConvertedComp.isna().sum()
# Out:
# 0

# %%
df5.count()
# Out:
# Respondent              11325
# MainBranch              11325
# Hobbyist                11325
# OpenSourcer             11325
# OpenSource              11244
#                         ...
# Ethnicity               10672
# Dependents              11186
# SurveyLength            11306
# SurveyEase              11311
# NormalizedAnnualComp    10519
# Length: 86, dtype: int64

# %%
df5.groupby(df5.Gender).ConvertedComp.median()
# Out:
# Gender
# Man                                                            57287.0
# Man;Non-binary, genderqueer, or gender non-conforming          59520.0
# Non-binary, genderqueer, or gender non-conforming              57751.0
# Woman                                                          57287.0
# Woman;Man                                                      25887.0
# Woman;Man;Non-binary, genderqueer, or gender non-conforming    30244.0
# Woman;Non-binary, genderqueer, or gender non-conforming        65535.5
# Name: ConvertedComp, dtype: float64

# %%
df5.ConvertedComp.hist()
# Out:
# <AxesSubplot:>

# %%
df5.ConvertedComp.mean()
# Out:
# 58853.25015452538

# %%
df5.ConvertedComp.median()
# Out:
# 57287.0

# %%
df=df5

# %%
df7=df.copy()

# %%
df7['GenderNew']=pd.np.where((df7.Gender=='Man'),(df7.Gender),
                        pd.np.where((df7.Gender=='Woman'),(df7.Gender),'Other'))

# %%
df7.GenderNew.value_counts()
# Out:
# Man      10480
# Woman      731
# Other      114
# Name: GenderNew, dtype: int64

# %%
# Created a new column 'GenderNew' with 3 categories - Man, Woman and Other.
# Respondent identifying as non-bnary, non-conforming or genderqueer are categorised under 'Other'.

# %%
df=df7

# %%
df8=df.copy()

# %%
df8.groupby('Country').ConvertedComp.mean().sort_values(ascending=False).head(25)
# Out:
# Country
# Somalia           103176.000000
# United States      93957.107603
# Israel             88401.235294
# Iceland            81359.166667
# Panama             81000.000000
# Norway             79708.904762
# Switzerland        79368.062069
# Denmark            79070.085366
# Australia          71655.891228
# Luxembourg         71600.000000
# Ireland            69291.878788
# Canada             68125.313953
# Uzbekistan         68000.000000
# New Zealand        64177.726027
# United Kingdom     62183.610024
# Jordan             61995.285714
# Singapore          60487.406250
# Swaziland          58876.333333
# Germany            58861.707143
# Sweden             58361.281250
# Qatar              57751.000000
# Mozambique         57751.000000
# Cape Verde         57751.000000
# Kuwait             57519.000000
# Liechtenstein      57287.000000
# Name: ConvertedComp, dtype: float64

# %%
df8.groupby('Country').ConvertedComp.mean().sort_values(ascending=False).head(25).sort_values(ascending=True).plot.barh(color=['red','blue','green','brown','orange'])
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
df8.loc[(df8.Country=='Liechtenstein')]
# Out:
#       Respondent MainBranch Hobbyist              OpenSourcer  \
# 2165        4434  Developer      Yes  Less than once per year
#
#                                              OpenSource          Employment  \
# 2165  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#             Country Student  \
# 2165  Liechtenstein      No
#
#                                                 EdLevel UndergradMajor  \
# 2165  Secondary school (e.g. American high school, G...            NaN
#
#                                                EduOther             OrgSize  \
# 2165  Taken an online course in programming or softw...  20 to 99 employees
#
#                     DevType YearsCode Age1stCode YearsCodePro  \
# 2165  Developer, full-stack         6         14            3
#
#                CareerSat          JobSat            MgrIdiot MgrMoney  \
# 2165  Slightly satisfied  Very satisfied  Somewhat confident      Yes
#
# ...

# %%
df8.CareerSat.value_counts()
# Out:
# Very satisfied                        4748
# Slightly satisfied                    4036
# Slightly dissatisfied                 1115
# Neither satisfied nor dissatisfied     924
# Very dissatisfied                      502
# Name: CareerSat, dtype: int64

# %%
df8.groupby('CareerSat').Respondent.count().sort_values(ascending=False).head(25).sort_values(ascending=True).plot.barh(color=['red','blue','green','brown','orange'])
# Out:
# <AxesSubplot:ylabel='CareerSat'>

# %%
# Horizontal bar chart of Career Satisfaction

# %%
df9=df.copy()

# %%
df9.WorkWeekHrs.isna().sum()
# Out:
# 122

# %%
df9.WorkWeekHrs.fillna(df9.WorkWeekHrs.median(),inplace=True)

# %%
df9.WorkWeekHrs.isna().sum()
# Out:
# 0

# %%
(df9.WorkWeekHrs>105).sum()
# Out:
# 88

# %%
df9.WorkWeekHrs=df9.WorkWeekHrs.clip(0,105)

# %%
(df9.WorkWeekHrs>105).sum()
# Out:
# 0

# %%
df9.WorkWeekHrs.median()
# Out:
# 40.0

# %%
plt.figure(figsize=(8,5))
plt.scatter(df9.Age,df9.WorkWeekHrs,alpha=0.3,c='LightGreen',edgecolor='Orange',linewidths=.8)
plt.xlabel('Age')
plt.ylabel('Hours worked per Week')
# Out:
# Text(0, 0.5, 'Hours worked per Week')

# %%
# Scatter plot of Age and WorkWeekHrs

# %%
df=df9

# %%
df.Employment.value_counts('a')*100
# Out:
# Employed full-time    96.229581
# Employed part-time     3.770419
# Name: Employment, dtype: float64

# %%
# Percentage of developers employed Full-time and part-time.

# %%
df10=df.filter(['Respondent','DatabaseDesireNextYear'])
df10
# Out:
#        Respondent                             DatabaseDesireNextYear
# 0               4                                       MySQL;SQLite
# 1               9                            PostgreSQL;Redis;SQLite
# 2              13                               Firebase;MySQL;Redis
# 3              16  Elasticsearch;MongoDB;Microsoft SQL Server;SQLite
# 4              17          Elasticsearch;Firebase;MongoDB;PostgreSQL
# ...           ...                                                ...
# 11547       25136                               Microsoft SQL Server
# 11548       25137                              MariaDB;MongoDB;MySQL
# 11549       25138                                                NaN
# 11550       25141   Elasticsearch;MongoDB;Microsoft SQL Server;Redis
# 11551       25142                                         PostgreSQL
#
# [11325 rows x 2 columns]

# %%
df10['DatabaseDesireNextYear']=df10.DatabaseDesireNextYear.str.split(';')
df10
# Out:
#        Respondent                             DatabaseDesireNextYear
# 0               4                                    [MySQL, SQLite]
# 1               9                        [PostgreSQL, Redis, SQLite]
# 2              13                           [Firebase, MySQL, Redis]
# 3              16  [Elasticsearch, MongoDB, Microsoft SQL Server,...
# 4              17     [Elasticsearch, Firebase, MongoDB, PostgreSQL]
# ...           ...                                                ...
# 11547       25136                             [Microsoft SQL Server]
# 11548       25137                          [MariaDB, MongoDB, MySQL]
# 11549       25138                                                NaN
# 11550       25141  [Elasticsearch, MongoDB, Microsoft SQL Server,...
# 11551       25142                                       [PostgreSQL]
#
# [11325 rows x 2 columns]

# %%
# Converted DatabaseDesireNextYear to list.

# %%
df10=df10.explode('DatabaseDesireNextYear')
df10
# Out:
#        Respondent DatabaseDesireNextYear
# 0               4                  MySQL
# 0               4                 SQLite
# 1               9             PostgreSQL
# 1               9                  Redis
# 1               9                 SQLite
# ...           ...                    ...
# 11550       25141          Elasticsearch
# 11550       25141                MongoDB
# 11550       25141   Microsoft SQL Server
# 11550       25141                  Redis
# 11551       25142             PostgreSQL
#
# [30414 rows x 2 columns]

# %%
df10.DatabaseDesireNextYear.value_counts()
# Out:
# PostgreSQL              4300
# MongoDB                 3623
# Redis                   3316
# MySQL                   3258
# Elasticsearch           2842
# Microsoft SQL Server    2691
# SQLite                  2419
# Firebase                1640
# MariaDB                 1365
# DynamoDB                1042
# Cassandra               1001
# Oracle                   862
# Other(s):                638
# Couchbase                385
# Name: DatabaseDesireNextYear, dtype: int64

# %%
df11=df10.DatabaseDesireNextYear.value_counts().head(5)
df11
# Out:
# PostgreSQL       4300
# MongoDB          3623
# Redis            3316
# MySQL            3258
# Elasticsearch    2842
# Name: DatabaseDesireNextYear, dtype: int64

# %%
# Top 5 Desired Databases For Next Year

# %%
plt.figure(figsize=(6,6))
labels=['PostgreSQL','MongoDB','MySQL','Redis','Elasticsearch']
plt.pie(df11,labels=labels,autopct='%.2f%%',shadow=True,explode=[0.1]*len(labels))
plt.title('Top 5 Desired Databases For Next Year')
# Out:
# Text(0.5, 1.0, 'Top 5 Desired Databases For Next Year')

# %%
# Pie chart representing the Top 5 Desired Databases that respondents wish to learn Next Year.

# %%
#blank

# %%
df12=df.filter(['Respondent','DatabaseWorkedWith'])
df12
# Out:
#        Respondent                  DatabaseWorkedWith
# 0               4                        MySQL;SQLite
# 1               9          DynamoDB;PostgreSQL;SQLite
# 2              13   Couchbase;DynamoDB;Firebase;MySQL
# 3              16  MongoDB;Microsoft SQL Server;MySQL
# 4              17                  MongoDB;PostgreSQL
# ...           ...                                 ...
# 11547       25136                Microsoft SQL Server
# 11548       25137                               MySQL
# 11549       25138                          PostgreSQL
# 11550       25141          Microsoft SQL Server;Redis
# 11551       25142                          PostgreSQL
#
# [11325 rows x 2 columns]

# %%
df12['DatabaseWorkedWith']=df12.DatabaseWorkedWith.str.split(';')
df12
# Out:
#        Respondent                      DatabaseWorkedWith
# 0               4                         [MySQL, SQLite]
# 1               9          [DynamoDB, PostgreSQL, SQLite]
# 2              13  [Couchbase, DynamoDB, Firebase, MySQL]
# 3              16  [MongoDB, Microsoft SQL Server, MySQL]
# 4              17                   [MongoDB, PostgreSQL]
# ...           ...                                     ...
# 11547       25136                  [Microsoft SQL Server]
# 11548       25137                                 [MySQL]
# 11549       25138                            [PostgreSQL]
# 11550       25141           [Microsoft SQL Server, Redis]
# 11551       25142                            [PostgreSQL]
#
# [11325 rows x 2 columns]

# %%
# Converted DatabaseWorkedWith to list.

# %%
df12=df12.explode('DatabaseWorkedWith')
df12
# Out:
#        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 0               4                SQLite
# 1               9              DynamoDB
# 1               9            PostgreSQL
# 1               9                SQLite
# ...           ...                   ...
# 11548       25137                 MySQL
# 11549       25138            PostgreSQL
# 11550       25141  Microsoft SQL Server
# 11550       25141                 Redis
# 11551       25142            PostgreSQL
#
# [31600 rows x 2 columns]

# %%
df12.DatabaseWorkedWith.value_counts()
# Out:
# MySQL                   5429
# Microsoft SQL Server    4083
# PostgreSQL              4071
# SQLite                  3227
# MongoDB                 2994
# Redis                   2497
# Elasticsearch           1940
# Oracle                  1726
# MariaDB                 1689
# Firebase                1306
# DynamoDB                 827
# Other(s):                720
# Cassandra                393
# Couchbase                247
# Name: DatabaseWorkedWith, dtype: int64

# %%
df13=df12.DatabaseWorkedWith.value_counts().head(5)
df13
# Out:
# MySQL                   5429
# Microsoft SQL Server    4083
# PostgreSQL              4071
# SQLite                  3227
# MongoDB                 2994
# Name: DatabaseWorkedWith, dtype: int64

# %%
# Top 5 Databases Worked with.

# %%
plt.figure(figsize=(6,6))
labels=['MySQL','Microsoft SQL Server','PostgreSQL','SQLite','MongoDB']
plt.pie(df13,labels=labels,autopct='%.2f%%',shadow=True,explode=[0.1]*len(labels))
plt.title('Top 5 Databases Worked with')
# Out:
# Text(0.5, 1.0, 'Top 5 Databases Worked with')

# %%
# Pie chart representing Top 5 Databases Worked with.

# %%
#blank

# %%
df14=df.filter(['Respondent','LanguageDesireNextYear'])
df14
# Out:
#        Respondent                             LanguageDesireNextYear
# 0               4                                C;C#;JavaScript;SQL
# 1               9  Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# 2              13  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 3              16  C#;HTML/CSS;JavaScript;TypeScript;WebAssembly;...
# 4              17  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# ...           ...                                                ...
# 11547       25136        C#;F#;JavaScript;SQL;TypeScript;WebAssembly
# 11548       25137                        HTML/CSS;JavaScript;PHP;SQL
# 11549       25138                                            C#;Java
# 11550       25141                                          C++;C#;F#
# 11551       25142               Bash/Shell/PowerShell;C;C++;Python;R
#
# [11325 rows x 2 columns]

# %%
df14['LanguageDesireNextYear']=df.LanguageDesireNextYear.str.split(';')
df14
# Out:
#        Respondent                             LanguageDesireNextYear
# 0               4                           [C, C#, JavaScript, SQL]
# 1               9  [Bash/Shell/PowerShell, C, HTML/CSS, JavaScrip...
# 2              13  [Bash/Shell/PowerShell, HTML/CSS, JavaScript, ...
# 3              16  [C#, HTML/CSS, JavaScript, TypeScript, WebAsse...
# 4              17  [Bash/Shell/PowerShell, HTML/CSS, Java, JavaSc...
# ...           ...                                                ...
# 11547       25136  [C#, F#, JavaScript, SQL, TypeScript, WebAssem...
# 11548       25137                   [HTML/CSS, JavaScript, PHP, SQL]
# 11549       25138                                         [C#, Java]
# 11550       25141                                      [C++, C#, F#]
# 11551       25142         [Bash/Shell/PowerShell, C, C++, Python, R]
#
# [11325 rows x 2 columns]

# %%
# Converted LanguageDesireNextYear to list.

# %%
df14=df14.explode('LanguageDesireNextYear')
df14
# Out:
#        Respondent LanguageDesireNextYear
# 0               4                      C
# 0               4                     C#
# 0               4             JavaScript
# 0               4                    SQL
# 1               9  Bash/Shell/PowerShell
# ...           ...                    ...
# 11551       25142  Bash/Shell/PowerShell
# 11551       25142                      C
# 11551       25142                    C++
# 11551       25142                 Python
# 11551       25142                      R
#
# [55488 rows x 2 columns]

# %%
df14.LanguageDesireNextYear.value_counts()
# Out:
# JavaScript               6581
# HTML/CSS                 5286
# Python                   5209
# SQL                      4977
# TypeScript               4057
# C#                       3562
# Bash/Shell/PowerShell    3070
# Java                     2933
# Go                       2744
# Kotlin                   1881
# C++                      1617
# Rust                     1513
# PHP                      1442
# WebAssembly              1384
# Swift                    1172
# Ruby                     1023
# C                        1018
# Scala                     877
# R                         845
# Other(s):                 823
# F#                        618
# Elixir                    614
# Dart                      605
# Clojure                   411
# Assembly                  330
# Erlang                    307
# Objective-C               306
# VBA                       149
# Name: LanguageDesireNextYear, dtype: int64

# %%
df15=df14.LanguageDesireNextYear.value_counts().head(5)
df15
# Out:
# JavaScript    6581
# HTML/CSS      5286
# Python        5209
# SQL           4977
# TypeScript    4057
# Name: LanguageDesireNextYear, dtype: int64

# %%
# Top 5 Desired Languages For Next Year.

# %%
plt.figure(figsize=(6,6))
labels=['JavaScript','HTML/CSS','Python','SQL','TypeScript']
plt.pie(df15,labels=labels,autopct='%.2f%%',shadow=True,explode=[0.1]*len(labels))
plt.title('Top 5 Desired Languages For Next Year')
# Out:
# Text(0.5, 1.0, 'Top 5 Desired Languages For Next Year')

# %%
# Pie chart representing Top 5 Desired Languages For Next Year.

# %%
#blank

# %%
df16=df.filter(['Respondent','LanguageWorkedWith'])
df16
# Out:
#        Respondent                                 LanguageWorkedWith
# 0               4                                C;C++;C#;Python;SQL
# 1               9  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 2              13  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 3              16  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 4              17  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Type...
# ...           ...                                                ...
# 11547       25136                 C#;F#;HTML/CSS;Java;JavaScript;SQL
# 11548       25137                        HTML/CSS;JavaScript;PHP;SQL
# 11549       25138  Assembly;Bash/Shell/PowerShell;C;C++;C#;Java;J...
# 11550       25141  Bash/Shell/PowerShell;C++;C#;HTML/CSS;Java;Jav...
# 11551       25142  Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;PHP;Py...
#
# [11325 rows x 2 columns]

# %%
df16['LanguageWorkedWith']=df.LanguageWorkedWith.str.split(';')
df16
# Out:
#        Respondent                                 LanguageWorkedWith
# 0               4                          [C, C++, C#, Python, SQL]
# 1               9  [Bash/Shell/PowerShell, C#, HTML/CSS, JavaScri...
# 2              13  [Bash/Shell/PowerShell, HTML/CSS, JavaScript, ...
# 3              16  [Bash/Shell/PowerShell, C#, HTML/CSS, JavaScri...
# 4              17  [Bash/Shell/PowerShell, HTML/CSS, JavaScript, ...
# ...           ...                                                ...
# 11547       25136          [C#, F#, HTML/CSS, Java, JavaScript, SQL]
# 11548       25137                   [HTML/CSS, JavaScript, PHP, SQL]
# 11549       25138  [Assembly, Bash/Shell/PowerShell, C, C++, C#, ...
# 11550       25141  [Bash/Shell/PowerShell, C++, C#, HTML/CSS, Jav...
# 11551       25142  [Bash/Shell/PowerShell, C, C++, Go, HTML/CSS, ...
#
# [11325 rows x 2 columns]

# %%
# Converted LanguageWorkedWith to list.

# %%
df16=df16.explode('LanguageWorkedWith')
df16
# Out:
#        Respondent LanguageWorkedWith
# 0               4                  C
# 0               4                C++
# 0               4                 C#
# 0               4             Python
# 0               4                SQL
# ...           ...                ...
# 11551       25142                 Go
# 11551       25142           HTML/CSS
# 11551       25142                PHP
# 11551       25142             Python
# 11551       25142                  R
#
# [59374 rows x 2 columns]

# %%
df16.LanguageWorkedWith.value_counts()
# Out:
# JavaScript               8627
# HTML/CSS                 7776
# SQL                      7057
# Bash/Shell/PowerShell    4604
# Python                   4512
# Java                     4482
# C#                       4253
# TypeScript               3211
# PHP                      2887
# C++                      1930
# C                        1563
# Ruby                     1142
# Go                       1108
# Other(s):                 831
# Kotlin                    746
# Swift                     703
# VBA                       619
# R                         581
# Objective-C               515
# Scala                     490
# Assembly                  430
# Rust                      323
# Dart                      235
# Elixir                    186
# Clojure                   164
# F#                        158
# WebAssembly               133
# Erlang                     97
# Name: LanguageWorkedWith, dtype: int64

# %%
df17=df16.LanguageWorkedWith.value_counts().head(5)
df17
# Out:
# JavaScript               8627
# HTML/CSS                 7776
# SQL                      7057
# Bash/Shell/PowerShell    4604
# Python                   4512
# Name: LanguageWorkedWith, dtype: int64

# %%
# 7057 respondents currently work with or have worked with SQL

# %%
# Top 5 Languages worked with.

# %%
plt.figure(figsize=(6,6))
labels=['JavaScript','HTML/CSS','SQL','Bash/Shell/PowerShell','Java']
plt.pie(df17,labels=labels,autopct='%.2f%%',shadow=True,explode=[0.1]*len(labels))
plt.title('Top 5 Languages worked with')
# Out:
# Text(0.5, 1.0, 'Top 5 Languages worked with')

# %%
# Pie chart representing Top 5 Languages worked with.

# %%
df18=df[(df.Age>29) & (df.Age<36)]
df18
# Out:
#        Respondent MainBranch Hobbyist  \
# 5              19  Developer      Yes
# 11             26  Developer      Yes
# 12             29  Developer      Yes
# 18             49  Developer      Yes
# 22             56  Developer       No
# ...           ...        ...      ...
# 11539       25120  Developer      Yes
# 11545       25133  Developer       No
# 11546       25134  Developer      Yes
# 11549       25138  Developer      Yes
# 11551       25142  Developer      Yes
#
#                                              OpenSourcer  \
# 5                                                  Never
# 11                               Less than once per year
# 12     Less than once a month but more than once per ...
# 18                               Less than once per year
# 22                                                 Never
# ...                                                  ...
# 11539                            Less than once per year
# ...

# %%
df18.WorkWeekHrs.median()
# Out:
# 40.0

# %%
# The median of working hoursper week for respondents between the age of 30 and 35 is 40 hours.

# %%
from PIL import Image

# %%
from wordcloud import WordCloud, ImageColorGenerator

# %%
text=df12.DatabaseWorkedWith[0:]

# %%
wordcloud = WordCloud(background_color="white").generate(str(text))

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                           1461
# Developer, back-end                                                                                                                                                                                                                                                                              751
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                                                                                   445
# ...

# %%
df19=df.filter(['Respondent','DevType'])
df19['DevType']=df19.DevType.str.split(';')
df19=df19.explode('DevType')
df19.DevType.value_counts()
# Out:
# Developer, full-stack                            6881
# Developer, back-end                              6249
# Developer, front-end                             3890
# Developer, desktop or enterprise applications    2549
# Developer, mobile                                1948
# DevOps specialist                                1627
# Database administrator                           1397
# System administrator                             1190
# Designer                                          979
# Developer, QA or test                             905
# Developer, embedded applications or devices       846
# Engineer, data                                    826
# Data scientist or machine learning specialist     797
# Data or business analyst                          796
# Student                                           760
# Academic researcher                               549
# Educator                                          510
# ...

# %%
# 6881 are Full-stack developers
# 796 are data/business analyst

# %%
df.EdLevel.value_counts()
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              5819
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           2690
# Some college/university study without earning a degree                                1351
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     509
# Associate degree                                                                       379
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              258
# Professional degree (JD, MD, etc.)                                                     154
# I never completed any formal education                                                  28
# Primary/elementary school                                                               26
# Name: EdLevel, dtype: int64

# %%
df.groupby('EdLevel').median().index.get_level_values(0)
# Out:
# Index(['Associate degree', 'Bachelor’s degree (BA, BS, B.Eng., etc.)',
#        'I never completed any formal education',
#        'Master’s degree (MA, MS, M.Eng., MBA, etc.)',
#        'Other doctoral degree (Ph.D, Ed.D., etc.)',
#        'Primary/elementary school', 'Professional degree (JD, MD, etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Some college/university study without earning a degree'],
#       dtype='object', name='EdLevel')

# %%
plt.figure(figsize=(12,12))
labels=df.groupby('EdLevel').median().index.get_level_values(0)
plt.pie(df.EdLevel.value_counts().sort_values(),autopct='%.2f%%',explode=[0.7,0.7,0.5,0.5,0.3,0.3,0,0,0])
plt.legend(labels,loc=(0.85,0.8))
plt.title('Education Level of Respondents')
# Out:
# Text(0.5, 1.0, 'Education Level of Respondents')

# %%
df.JobSat.value_counts()
# Out:
# Slightly satisfied                    3956
# Very satisfied                        3515
# Slightly dissatisfied                 1811
# Neither satisfied nor dissatisfied    1275
# Very dissatisfied                      767
# Name: JobSat, dtype: int64

# %%
df.groupby('JobSat').Respondent.count().sort_values(ascending=True).plot.barh()
# Out:
# <AxesSubplot:ylabel='JobSat'>

# %%
# Takeaways from this dataset - 

# - Average age of the respondents is 30.7 years.
# - Most people work from their office.
# - The median compensation of the respondents is $57,745.
# - On an average, the compensation in Western and European countries is higher than rest of the world.
# - JavaScript is the most used programming language.
# - JavaScript is also the most desired language, while Python third-most desired language.
# - MySQL is the most used database.
# - 96.2% developers are employed full-time.
# - Most developers are satisfied with their jobs.
# - More than 50% respondents working as developers do not have a degree from a University.
